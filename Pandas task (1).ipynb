# %%
import pandas as pd
import numpy as np

file_path = 'C:/Users/Maks/Desktop/Energy Indicators.xls'

energy = pd.read_excel(file_path, skiprows=17, header=None, skipfooter=38)
energy = energy.drop([0, 1], axis=1)
energy.columns = ['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
energy['Energy Supply'] = energy['Energy Supply'] * 1000000
energy = energy.replace('...', np.NaN)
energy['Country'] = energy['Country'].replace({'Republic of Korea': 'South Korea',
'United States of America': 'United States',
'United Kingdom of Great Britain and Northern Ireland': 'United Kingdom',
'China': 'Hong Kong', 'Hong Kong Special Administrative Region': 'Hong Kong'})
energy['Country'] = energy['Country'].str.replace(r'\(.*\)', '')  # Видалення дужок
energy['Country'] = energy['Country'].str.replace(r'\d+', '')  # Видалення чисел

energy
# Out:
#                        Country  \
# 0                          NaN
# 1                  Afghanistan
# 2                      Albania
# 3                      Algeria
# 4               American Samoa
# ..                         ...
# 223                   Viet Nam
# 224  Wallis and Futuna Islands
# 225                      Yemen
# 226                     Zambia
# 227                   Zimbabwe
#
#                                          Energy Supply  \
# 0    PetajoulesPetajoulesPetajoulesPetajoulesPetajo...
# 1                                            321000000
# 2                                            102000000
# 3                                           1959000000
# 4    .................................................
# ..                                                 ...
# 223                                         2554000000
# 224                                                  0
# 225                                          344000000
# ...

# %%
import pandas as pd

file_path = 'C:/Users/Maks/Desktop/API_NY.GDP.MKTP.CD_DS2_en_csv_v2_5871885.csv'

GDP = pd.read_csv(file_path, header=2)
GDP = GDP.rename(columns={'Country Name': 'Country'})
GDP['Country'] = GDP['Country'].replace({
    'Korea, Rep.': 'South Korea',
    'Iran, Islamic Rep.': 'Iran',
    'Hong Kong SAR, China': 'Hong Kong'
})
GDP
# Out:
#                          Country Country Code     Indicator Name  \
# 0                          Aruba          ABW  GDP (current US$)
# 1    Africa Eastern and Southern          AFE  GDP (current US$)
# 2                    Afghanistan          AFG  GDP (current US$)
# 3     Africa Western and Central          AFW  GDP (current US$)
# 4                         Angola          AGO  GDP (current US$)
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  GDP (current US$)
# 262                  Yemen, Rep.          YEM  GDP (current US$)
# 263                 South Africa          ZAF  GDP (current US$)
# 264                       Zambia          ZMB  GDP (current US$)
# 265                     Zimbabwe          ZWE  GDP (current US$)
#
#      Indicator Code          1960          1961          1962          1963  \
# 0    NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# ...

# %%
import pandas as pd

file_path = 'C:/Users/Maks/Desktop/scimagojr country rank 1996-2022.xlsx'

ScimEn = pd.read_excel(file_path)

ScimEn
# Out:
#      Rank                           Country            Region  Documents  \
# 0       1                             China    Asiatic Region     360468
# 1       2                     United States  Northern America     199442
# 2       3                             India    Asiatic Region      76103
# 3       4                             Japan    Asiatic Region      56249
# 4       5                    United Kingdom    Western Europe      52572
# ..    ...                               ...               ...        ...
# 207   208                             Palau    Pacific Region          1
# 208   209                        Montserrat     Latin America          1
# 209   210  Saint Vincent and the Grenadines     Latin America          1
# 210   211                     Guinea-Bissau            Africa          1
# 211   212    British Indian Ocean Territory            Africa          1
#
#      Citable documents  Citations  Self-citations  Citations per document  \
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
merged = pd.merge(ScimEn, energy, on='Country', how='inner')
merged = pd.merge(merged, GDP, on='Country', how='inner')
GDP = GDP[['Country', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']]
answer_one = pd.merge(ScimEn, energy, how='inner', left_on='Country', right_on='Country')
answer_one = pd.merge(answer_one, GDP, how='inner', left_on='Country', right_on='Country')

answer_one.set_index('Country', inplace=True)
answer_one = answer_one[answer_one['Rank'] <= 15]

answer_one
# Out:
#                     Rank            Region  Documents  Citable documents  \
# Country
# India                  3    Asiatic Region      76103              74167
# Germany                6    Western Europe      47781              46767
# Russian Federation     7    Eastern Europe      43567              43290
# Canada                 8  Northern America      39036              38276
# South Korea           10    Asiatic Region      35294              35005
# Brazil                15     Latin America      25887              25493
#
#                     Citations  Self-citations  Citations per document  \
# Country
# India                  760964          280893                   10.00
# Germany                641717          133693                   13.43
# Russian Federation     175721           79765                    4.03
# Canada                 787010          125333                   20.16
# South Korea            503147           87529                   14.26
# ...
